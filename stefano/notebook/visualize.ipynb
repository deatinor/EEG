# %% [markdown]
# In this notebook we visualize the data

# %% [markdown]
# # Import

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

# %%
import load_script

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Loading the dataset

# %%
train_dataset,target=load_script.load_dataset(train=True,single_target=True)

# %%
test_dataset,test_target=load_script.load_dataset(train=False,single_target=True)

# %%
numpy_dataset=train_dataset.data.numpy()
numpy_target=target.data.numpy()

# %% [markdown]
# # Visualization

# %%
index=0
sample=numpy_dataset[index]

# %%
feature=2

# for i in range(1):
#     if numpy_target[i]==1:
#         sample=(numpy_dataset[i][:-1]+numpy_dataset[i][1:])/2
#         plt.plot(sample[feature])
# plt.show()

for i in range(1):
    if numpy_target[i]==0:
        sample=numpy_dataset[i]
        sample=(sample[:,1:]+sample[:,:-1])/2
        plt.plot(sample[feature])
plt.show()

# %%
for i in range(20):
    if numpy_target[i]==0:
        sample=numpy_dataset[i]
        plt.plot(sample[0])
plt.show()

# %%
for i in range(20):
    if numpy_target[i]==0:
        sample=numpy_dataset[i]
        plt.plot(sample[1])
plt.show()
